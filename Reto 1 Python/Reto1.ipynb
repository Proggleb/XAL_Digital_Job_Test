# %% [markdown]
# ## XAL DIGITAL

# %% [markdown]
# ### RETO DE PROGRAMACIÓN

# %% [markdown]
# El siguiente es un reto de programación realizado en Python, comentando el tipo de análisis y seguimiento en la resolución del reto, no sólo para presentar la solución si no el proceso de trabajo.

# %% [markdown]
# -Caleb Aguilar Camargo, 22 de junio del 2022

# %% [markdown]
# ## Instrucciones

# %% [markdown]
# Se deberá desarrollar un proceso de análisis de datos utilizando el siguiente enlace: https://api.stackexchange.com/2.2/search?order=desc&sort=activity&intitle=perl&site=stackoverflow.
#
# El proceso debe realizar las siguientes actividades:
#
#     1. Conectarse al enlace
#     2. Obtener el número de respuestas contestadas y no contestadas
#     3. Obtener la respuesta con menor número de vistas
#     4. Obtener la respuesta más vieja y más actual
#     5. Obtener la respuesta del owner que tenga una mayor reputación
#     6. Imprimir en consola del punto 2 al 5

# %% [markdown]
# ## 1. Conectarse al enlace

# %% [markdown]
# Existen diversas formas de resolver este problema en particular, accediendo al enlace podemos observar que se trata de un archivo tipo JSON, y que para este caso en particular, es bastante pequeño, por lo que podríamos guardarlo en nuestro computador de trabajo como un archivo con esa extensión... (Durante el desarrollo del reto, observé que este enlace muestra en tiempo real las preguntas más recientes sobre el tópico "perl", por lo que ésta opción quedaría descartada)
#
# Para efectos de esta práctica utilizaremos otro método que es conectandonos directamente al enlace.

# %%
#Importamos las librerias necesarias
import requests
import json

# %%
#Vamos a familiarizarnos con el JSON
r = requests.get('https://api.stackexchange.com/2.2/search?order=desc&sort=activity&intitle=perl&site=stackoverflow')
j = json.dumps(r.json(), indent=4)
print(j)
# Out:
# {
#     "items": [
#         {
#             "tags": [
#                 "perl",
#                 "whitespace",
#                 "regex-lookarounds",
#                 "brackets"
#             ],
#             "owner": {
#                 "reputation": 1174,
#                 "user_id": 1461307,
#                 "user_type": "registered",
#                 "profile_image": "https://i.stack.imgur.com/zhYSU.png?s=256&g=1",
#                 "display_name": "Jacob Wegelin",
#                 "link": "https://stackoverflow.com/users/1461307/jacob-wegelin"
#             },
#             "is_answered": false,
#             "view_count": 45,
#             "answer_count": 0,
#             "score": 0,
#             "last_activity_date": 1655928853,
#             "creation_date": 1655911307,
#             "last_edit_date": 1655928853,
#             "question_id": 72718127,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/72718127/how-can-i-prevent-matching-an-all-whitespace-line-inside-brackets-with-perl-rege",
#             "title": "how can I prevent matching an all-whitespace line inside brackets with perl regex?"
#         },
#         {
#             "tags": [
#                 "perl",
#                 "mime"
#             ],
#             "owner": {
#                 "reputation": 91,
#                 "user_id": 4933923,
#                 "user_type": "registered",
#                 "accept_rate": 20,
#                 "profile_image": "https://graph.facebook.com/815283951882645/picture?type=large",
#                 "display_name": "Pankaj Kumar",
#                 "link": "https://stackoverflow.com/users/4933923/pankaj-kumar"
#             },
#             "is_answered": true,
#             "view_count": 25,
#             "answer_count": 1,
#             "score": 1,
#             "last_activity_date": 1655926377,
#             "creation_date": 1655925551,
#             "last_edit_date": 1655926377,
#             "question_id": 72720942,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/72720942/how-to-create-html-tables-dynamically-using-perl",
#             "title": "How to create HTML tables dynamically using Perl?"
#         },
#         {
#             "tags": [
#                 "perl"
#             ],
#             "owner": {
#                 "reputation": 235,
#                 "user_id": 10704132,
#                 "user_type": "registered",
#                 "profile_image": "https://www.gravatar.com/avatar/b78ac0af40e7ae7ab624b4ada8f5f22c?s=256&d=identicon&r=PG&f=1",
#                 "display_name": "santa100",
#                 "link": "https://stackoverflow.com/users/10704132/santa100"
#             },
#             "is_answered": false,
#             "view_count": 27,
#             "closed_date": 1655909054,
#             "answer_count": 0,
#             "score": -2,
#             "last_activity_date": 1655908639,
#             "creation_date": 1655908639,
#             "question_id": 72717520,
#             "link": "https://stackoverflow.com/questions/72717520/does-this-years-perl-conference-2022-provide-free-live-stream",
#             "closed_reason": "Not suitable for this site",
#             "title": "Does this year&#39;s Perl Conference 2022 provide free live stream?"
#         },
#         {
#             "tags": [
#                 "regex",
#                 "perl"
#             ],
#             "owner": {
#                 "reputation": 28046,
#                 "user_id": 377031,
#                 "user_type": "registered",
#                 "accept_rate": 92,
#                 "profile_image": "https://www.gravatar.com/avatar/a9b4665d4dbfd73810f0de38d4627013?s=256&d=identicon&r=PG",
#                 "display_name": "David B",
#                 "link": "https://stackoverflow.com/users/377031/david-b"
#             },
#             "is_answered": true,
#             "view_count": 27411,
#             "accepted_answer_id": 3439134,
#             "answer_count": 7,
#             "score": 21,
#             "last_activity_date": 1655895047,
#             "creation_date": 1281349700,
#             "last_edit_date": 1493563395,
#             "question_id": 3439123,
#             "content_license": "CC BY-SA 3.0",
#             "link": "https://stackoverflow.com/questions/3439123/how-can-i-match-everything-that-is-after-the-last-occurrence-of-some-char-in-a-p",
#             "title": "How can I match everything that is after the last occurrence of some char in a perl regular expression?"
#         },
#         {
#             "tags": [
#                 "perl"
#             ],
#             "owner": {
#                 "reputation": 1,
#                 "user_id": 16312046,
#                 "user_type": "registered",
#                 "profile_image": "https://lh3.googleusercontent.com/a/AATXAJyFdH4hMHHkpArYDWM6kvZhci4PpIIy4cOJbBZW=k-s256",
#                 "display_name": "Rasheed Mohammed",
#                 "link": "https://stackoverflow.com/users/16312046/rasheed-mohammed"
#             },
#             "is_answered": true,
#             "view_count": 56,
#             "answer_count": 2,
#             "score": 0,
#             "last_activity_date": 1655867964,
#             "creation_date": 1655849889,
#             "last_edit_date": 1655854801,
#             "question_id": 72707679,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/72707679/how-to-print-an-element-from-an-array-which-is-inside-the-hash-in-perl",
#             "title": "How to print an element from an array which is inside the hash in perl"
#         },
#         {
#             "tags": [
#                 "python",
#                 "ruby",
#                 "perl",
#                 "bash",
#                 "shell"
#             ],
#             "owner": {
#                 "reputation": 22788,
#                 "user_id": 336455,
#                 "user_type": "registered",
#                 "accept_rate": 90,
#                 "profile_image": "https://www.gravatar.com/avatar/bf99e9cac9b699222adb938e2c3db7a8?s=256&d=identicon&r=PG",
#                 "display_name": "Muhammad Alkarouri",
#                 "link": "https://stackoverflow.com/users/336455/muhammad-alkarouri"
#             },
#             "is_answered": true,
#             "view_count": 66131,
#             "protected_date": 1346935333,
#             "closed_date": 1368215053,
#             "accepted_answer_id": 3640403,
#             "answer_count": 12,
#             "score": 347,
#             "last_activity_date": 1655845162,
#             "creation_date": 1283531098,
#             "last_edit_date": 1655150834,
#             "question_id": 3637668,
#             "link": "https://stackoverflow.com/questions/3637668/why-are-scripting-languages-e-g-perl-python-and-ruby-not-suitable-as-shell",
#             "closed_reason": "not constructive",
#             "title": "Why are scripting languages (e.g. Perl, Python, and Ruby) not suitable as shell languages?"
#         },
#         {
#             "tags": [
#                 "perl"
#             ],
#             "owner": {
#                 "reputation": 1,
#                 "user_id": 19382522,
#                 "user_type": "registered",
#                 "profile_image": "https://lh3.googleusercontent.com/a-/AOh14GhaE_iP6QDbG43CjXkrYFguetZlex43vhPsF_ol=k-s256",
#                 "display_name": "haypenken",
#                 "link": "https://stackoverflow.com/users/19382522/haypenken"
#             },
#             "is_answered": false,
#             "view_count": 43,
#             "closed_date": 1655819601,
#             "answer_count": 0,
#             "score": -3,
#             "last_activity_date": 1655839593,
#             "creation_date": 1655815719,
#             "last_edit_date": 1655839593,
#             "question_id": 72701075,
#             "link": "https://stackoverflow.com/questions/72701075/perl-multiply-third-number-in-each-line-between-strings",
#             "closed_reason": "Needs details or clarity",
#             "title": "Perl - multiply third number in each line between strings?"
#         },
#         {
#             "tags": [
#                 "perl"
#             ],
#             "owner": {
#                 "reputation": 267,
#                 "user_id": 1574656,
#                 "user_type": "registered",
#                 "accept_rate": 38,
#                 "profile_image": "https://i.stack.imgur.com/KRy3Z.jpg?s=256&g=1",
#                 "display_name": "No Body",
#                 "link": "https://stackoverflow.com/users/1574656/no-body"
#             },
#             "is_answered": false,
#             "view_count": 10183,
#             "answer_count": 1,
#             "score": 1,
#             "last_activity_date": 1655838340,
#             "creation_date": 1383155733,
#             "last_edit_date": 1383160867,
#             "question_id": 19690370,
#             "content_license": "CC BY-SA 3.0",
#             "link": "https://stackoverflow.com/questions/19690370/how-to-redirect-a-page-in-perl-script",
#             "title": "How to redirect a page in perl script"
#         },
#         {
#             "tags": [
#                 "regex",
#                 "perl"
#             ],
#             "owner": {
#                 "reputation": 41,
#                 "user_id": 14035671,
#                 "user_type": "registered",
#                 "profile_image": "https://www.gravatar.com/avatar/39d7e31fdff8706f58e066cea8c62f17?s=256&d=identicon&r=PG&f=1",
#                 "display_name": "JimmyMoonstone",
#                 "link": "https://stackoverflow.com/users/14035671/jimmymoonstone"
#             },
#             "is_answered": true,
#             "view_count": 61,
#             "answer_count": 2,
#             "score": 2,
#             "last_activity_date": 1655832232,
#             "creation_date": 1655612700,
#             "question_id": 72674276,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/72674276/perl-how-to-remove-mulitline-numbers-with-a-regex",
#             "title": "Perl - How to remove mulitline numbers with a Regex"
#         },
#         {
#             "tags": [
#                 "powershell",
#                 "perl"
#             ],
#             "owner": {
#                 "reputation": 105,
#                 "user_id": 17323073,
#                 "user_type": "registered",
#                 "profile_image": "https://lh3.googleusercontent.com/a/AATXAJx3Zz77LVEHASQR-NnUT1AyNuOPx8izorvqRAhd=k-s256",
#                 "display_name": "postmaster 420",
#                 "link": "https://stackoverflow.com/users/17323073/postmaster-420"
#             },
#             "is_answered": false,
#             "view_count": 32,
#             "closed_date": 1655830416,
#             "answer_count": 0,
#             "score": -1,
#             "last_activity_date": 1655829885,
#             "creation_date": 1655829885,
#             "question_id": 72704398,
#             "link": "https://stackoverflow.com/questions/72704398/powershell-to-perl-reference-guide",
#             "closed_reason": "Not suitable for this site",
#             "title": "PowerShell to Perl reference guide"
#         },
#         {
#             "tags": [
#                 "perl",
#                 "webserver",
#                 "raku",
#                 "one-liner"
#             ],
#             "owner": {
#                 "reputation": 371,
#                 "user_id": 14812514,
#                 "user_type": "registered",
#                 "profile_image": "https://i.stack.imgur.com/rDtFz.jpg?s=256&g=1",
#                 "display_name": "uxer",
#                 "link": "https://stackoverflow.com/users/14812514/uxer"
#             },
#             "is_answered": true,
#             "view_count": 151,
#             "answer_count": 3,
#             "score": 5,
#             "last_activity_date": 1655825587,
#             "creation_date": 1655562850,
#             "last_edit_date": 1655573893,
#             "question_id": 72670076,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/72670076/perl-raku-succinct-webserver-one-liner",
#             "title": "Perl/Raku succinct webserver one-liner?"
#         },
#         {
#             "tags": [
#                 "perl",
#                 "documentation"
#             ],
#             "owner": {
#                 "reputation": 847,
#                 "user_id": 14055985,
#                 "user_type": "registered",
#                 "profile_image": "https://i.stack.imgur.com/A6il4.png?s=256&g=1",
#                 "display_name": "KJ7LNW",
#                 "link": "https://stackoverflow.com/users/14055985/kj7lnw"
#             },
#             "is_answered": true,
#             "view_count": 44,
#             "accepted_answer_id": 72702495,
#             "answer_count": 1,
#             "score": 1,
#             "last_activity_date": 1655821384,
#             "creation_date": 1655604461,
#             "question_id": 72673848,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/72673848/can-perl-pod-represent-quoting-from-an-email",
#             "title": "Can Perl POD represent quoting from an email?"
#         },
#         {
#             "tags": [
#                 "perl",
#                 "one-liner"
#             ],
#             "owner": {
#                 "reputation": 83,
#                 "user_id": 6562007,
#                 "user_type": "registered",
#                 "accept_rate": 100,
#                 "profile_image": "https://lh5.googleusercontent.com/-QWsomkOotYI/AAAAAAAAAAI/AAAAAAAACo4/UWgCqxfwhEw/photo.jpg?sz=256",
#                 "display_name": "eswues",
#                 "link": "https://stackoverflow.com/users/6562007/eswues"
#             },
#             "is_answered": true,
#             "view_count": 41,
#             "answer_count": 2,
#             "score": 1,
#             "last_activity_date": 1655801309,
#             "creation_date": 1655746132,
#             "question_id": 72690870,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/72690870/perl-lane-change-delimiter",
#             "title": "perl -lane change delimiter"
#         },
#         {
#             "tags": [
#                 "python",
#                 "perl"
#             ],
#             "owner": {
#                 "reputation": 327,
#                 "user_id": 11397243,
#                 "user_type": "registered",
#                 "profile_image": "https://i.stack.imgur.com/4wWG0.jpg?s=256&g=1",
#                 "display_name": "snoopyjc",
#                 "link": "https://stackoverflow.com/users/11397243/snoopyjc"
#             },
#             "is_answered": false,
#             "view_count": 62,
#             "answer_count": 1,
#             "score": 1,
#             "last_activity_date": 1655772804,
#             "creation_date": 1655503268,
#             "question_id": 72665191,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/72665191/more-perl-style-function-templates-in-python",
#             "title": "More perl style Function Templates in python"
#         },
#         {
#             "tags": [
#                 "perl",
#                 "moose"
#             ],
#             "owner": {
#                 "reputation": 1536,
#                 "user_id": 1405646,
#                 "user_type": "registered",
#                 "accept_rate": 75,
#                 "profile_image": "https://www.gravatar.com/avatar/6298d27969ef6491bb007b8a5177ff40?s=256&d=identicon&r=PG",
#                 "display_name": "daliaessam",
#                 "link": "https://stackoverflow.com/users/1405646/daliaessam"
#             },
#             "is_answered": true,
#             "view_count": 717,
#             "answer_count": 3,
#             "score": -1,
#             "last_activity_date": 1655744938,
#             "creation_date": 1407276638,
#             "question_id": 25149188,
#             "content_license": "CC BY-SA 3.0",
#             "link": "https://stackoverflow.com/questions/25149188/perl-moose-extend-child-class-from-parent-by-use-statement",
#             "title": "Perl Moose extend child class from Parent by Use statement"
#         },
#         {
#             "tags": [
#                 "perl",
#                 "scope"
#             ],
#             "owner": {
#                 "reputation": 1813,
#                 "user_id": 1336962,
#                 "user_type": "registered",
#                 "accept_rate": 65,
#                 "profile_image": "https://www.gravatar.com/avatar/7e5a1b6c0b2cbec48a5768822ec57493?s=256&d=identicon&r=PG",
#                 "display_name": "Sumit",
#                 "link": "https://stackoverflow.com/users/1336962/sumit"
#             },
#             "is_answered": true,
#             "view_count": 62893,
#             "accepted_answer_id": 19100461,
#             "answer_count": 4,
#             "score": 21,
#             "last_activity_date": 1655744838,
#             "creation_date": 1380561657,
#             "last_edit_date": 1655452243,
#             "question_id": 19100106,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/19100106/local-and-global-variables-in-perl",
#             "title": "Local and Global variables in perl"
#         },
#         {
#             "tags": [
#                 "perl",
#                 "unicode",
#                 "string"
#             ],
#             "owner": {
#                 "reputation": 1851,
#                 "user_id": 98778,
#                 "user_type": "registered",
#                 "accept_rate": 60,
#                 "profile_image": "https://www.gravatar.com/avatar/44999b12bbad1b498252b3ac60c3ab0f?s=256&d=identicon&r=PG",
#                 "display_name": "Maulin",
#                 "link": "https://stackoverflow.com/users/98778/maulin"
#             },
#             "is_answered": true,
#             "view_count": 26583,
#             "accepted_answer_id": 1974459,
#             "answer_count": 4,
#             "score": 29,
#             "last_activity_date": 1655731309,
#             "creation_date": 1262022733,
#             "last_edit_date": 1535482902,
#             "question_id": 1970660,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/1970660/how-can-i-guess-the-encoding-of-a-string-in-perl",
#             "title": "How can I guess the encoding of a string in Perl?"
#         },
#         {
#             "tags": [
#                 "reactjs",
#                 "perl"
#             ],
#             "owner": {
#                 "reputation": 3,
#                 "user_id": 13987268,
#                 "user_type": "registered",
#                 "profile_image": "https://lh6.googleusercontent.com/-jtUjUO1u3s8/AAAAAAAAAAI/AAAAAAAAAAA/AMZuuclH1KKQu71iIyE8nK76VAfzV6KrIA/photo.jpg?sz=256",
#                 "display_name": "Maghesan",
#                 "link": "https://stackoverflow.com/users/13987268/maghesan"
#             },
#             "is_answered": false,
#             "view_count": 22,
#             "answer_count": 0,
#             "score": -1,
#             "last_activity_date": 1655711880,
#             "creation_date": 1655711880,
#             "question_id": 72683874,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/72683874/perl-form-submit-data-to-reactjs",
#             "title": "Perl form submit data to reactjs"
#         },
#         {
#             "tags": [
#                 "perl",
#                 "pdl"
#             ],
#             "owner": {
#                 "reputation": 847,
#                 "user_id": 14055985,
#                 "user_type": "registered",
#                 "profile_image": "https://i.stack.imgur.com/A6il4.png?s=256&g=1",
#                 "display_name": "KJ7LNW",
#                 "link": "https://stackoverflow.com/users/14055985/kj7lnw"
#             },
#             "is_answered": true,
#             "view_count": 48,
#             "answer_count": 1,
#             "score": 2,
#             "last_activity_date": 1655711698,
#             "creation_date": 1655007107,
#             "last_edit_date": 1655711698,
#             "question_id": 72589437,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/72589437/does-perl-pdl-have-an-equivalent-of-mathroundnearest",
#             "title": "Does Perl PDL have an equivalent of Math::Round::nearest()?"
#         },
#         {
#             "tags": [
#                 "perl"
#             ],
#             "owner": {
#                 "reputation": 1635,
#                 "user_id": 1094999,
#                 "user_type": "registered",
#                 "accept_rate": 35,
#                 "profile_image": "https://i.stack.imgur.com/O5fnJ.png?s=256&g=1",
#                 "display_name": "auraham",
#                 "link": "https://stackoverflow.com/users/1094999/auraham"
#             },
#             "is_answered": false,
#             "view_count": 46,
#             "closed_date": 1655670763,
#             "answer_count": 0,
#             "score": -1,
#             "last_activity_date": 1655669365,
#             "creation_date": 1655669365,
#             "question_id": 72680020,
#             "link": "https://stackoverflow.com/questions/72680020/context-for-scalars-lists-and-hashes-in-perl",
#             "closed_reason": "Duplicate",
#             "title": "Context for scalars, lists, and hashes in Perl"
#         },
#         {
#             "tags": [
#                 "perl"
#             ],
#             "owner": {
#                 "reputation": 18621,
#                 "user_id": 4632019,
#                 "user_type": "registered",
#                 "accept_rate": 57,
#                 "profile_image": "https://www.gravatar.com/avatar/8937eb40752cf51c7da61bd4a322a4ef?s=256&d=identicon&r=PG&f=1",
#                 "display_name": "Eugen Konkov",
#                 "link": "https://stackoverflow.com/users/4632019/eugen-konkov"
#             },
#             "is_answered": true,
#             "view_count": 54,
#             "accepted_answer_id": 72679094,
#             "answer_count": 1,
#             "score": 2,
#             "last_activity_date": 1655661476,
#             "creation_date": 1655636799,
#             "last_edit_date": 1655650275,
#             "question_id": 72676329,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/72676329/what-is-corect-way-to-configure-path-to-packages-for-perl",
#             "title": "What is corect way to configure path to packages for perl?"
#         },
#         {
#             "tags": [
#                 "arrays",
#                 "regex",
#                 "perl"
#             ],
#             "owner": {
#                 "reputation": 13,
#                 "user_id": 11940693,
#                 "user_type": "registered",
#                 "profile_image": "https://lh5.googleusercontent.com/-2YVMLOWbqqU/AAAAAAAAAAI/AAAAAAAAAAA/ACHi3retXRR4_LAAqPy9x_WIwU9ZolTm7g/photo.jpg?sz=256",
#                 "display_name": "Vinayak Shettigar",
#                 "link": "https://stackoverflow.com/users/11940693/vinayak-shettigar"
#             },
#             "is_answered": true,
#             "view_count": 109,
#             "accepted_answer_id": 72531022,
#             "answer_count": 2,
#             "score": 1,
#             "last_activity_date": 1655579686,
#             "creation_date": 1654601845,
#             "last_edit_date": 1654681792,
#             "question_id": 72530540,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/72530540/perl-regex-new-line-and-no-character",
#             "title": "Perl Regex new line and no character"
#         },
#         {
#             "tags": [
#                 "perl"
#             ],
#             "owner": {
#                 "reputation": 3,
#                 "user_id": 18581919,
#                 "user_type": "registered",
#                 "profile_image": "https://www.gravatar.com/avatar/5f59c71a726622561618663920fa220b?s=256&d=identicon&r=PG",
#                 "display_name": "Dave123",
#                 "link": "https://stackoverflow.com/users/18581919/dave123"
#             },
#             "is_answered": true,
#             "view_count": 59,
#             "accepted_answer_id": 72671119,
#             "answer_count": 1,
#             "score": 0,
#             "last_activity_date": 1655571739,
#             "creation_date": 1655497868,
#             "last_edit_date": 1655497943,
#             "question_id": 72664514,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/72664514/perl-for-loop-issue-with-understanding-it",
#             "title": "perl for loop issue with understanding it"
#         },
#         {
#             "tags": [
#                 "perl",
#                 "glibc",
#                 "perl-packager",
#                 "pp-perl-par-packager"
#             ],
#             "owner": {
#                 "reputation": 23,
#                 "user_id": 4783045,
#                 "user_type": "registered",
#                 "profile_image": "https://graph.facebook.com/1622008311378014/picture?type=large",
#                 "display_name": "Fooad Taha",
#                 "link": "https://stackoverflow.com/users/4783045/fooad-taha"
#             },
#             "is_answered": true,
#             "view_count": 42,
#             "answer_count": 1,
#             "score": 1,
#             "last_activity_date": 1655561348,
#             "creation_date": 1655392977,
#             "last_edit_date": 1655482978,
#             "question_id": 72648233,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/72648233/compile-perl-script-using-parpacker-and-run-it-on-different-linux-versions",
#             "title": "compile perl script using par::packer and run it on different linux versions"
#         },
#         {
#             "tags": [
#                 "regex",
#                 "perl",
#                 "regex-group",
#                 "multiline"
#             ],
#             "owner": {
#                 "reputation": 644,
#                 "user_id": 2035207,
#                 "user_type": "registered",
#                 "accept_rate": 71,
#                 "profile_image": "https://www.gravatar.com/avatar/23407540c4b23ef4f9b4ef62677576ae?s=256&d=identicon&r=PG",
#                 "display_name": "h q",
#                 "link": "https://stackoverflow.com/users/2035207/h-q"
#             },
#             "is_answered": true,
#             "view_count": 51,
#             "accepted_answer_id": 72666003,
#             "answer_count": 1,
#             "score": 1,
#             "last_activity_date": 1655514446,
#             "creation_date": 1655483368,
#             "question_id": 72662310,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/72662310/perl-iterate-through-multiline-match",
#             "title": "Perl: iterate through multiline match"
#         },
#         {
#             "tags": [
#                 "perl",
#                 "encoding",
#                 "mariadb",
#                 "dbi",
#                 "diacritics"
#             ],
#             "owner": {
#                 "reputation": 2649,
#                 "user_id": 1236569,
#                 "user_type": "registered",
#                 "accept_rate": 75,
#                 "profile_image": "https://www.gravatar.com/avatar/f0f377976002909c580d08c57f3c3676?s=256&d=identicon&r=PG",
#                 "display_name": "giordano",
#                 "link": "https://stackoverflow.com/users/1236569/giordano"
#             },
#             "is_answered": false,
#             "view_count": 28,
#             "answer_count": 0,
#             "score": 1,
#             "last_activity_date": 1655486060,
#             "creation_date": 1655486060,
#             "question_id": 72662754,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/72662754/perl-mariadb-conflict-with-decoding-execute-failed-incorrect-string-value",
#             "title": "Perl/MariaDB: conflict with decoding (execute failed: Incorrect string value: &#39;\\xE4...&#39;)"
#         },
#         {
#             "tags": [
#                 "perl",
#                 "pdl"
#             ],
#             "owner": {
#                 "reputation": 847,
#                 "user_id": 14055985,
#                 "user_type": "registered",
#                 "profile_image": "https://i.stack.imgur.com/A6il4.png?s=256&g=1",
#                 "display_name": "KJ7LNW",
#                 "link": "https://stackoverflow.com/users/14055985/kj7lnw"
#             },
#             "is_answered": true,
#             "view_count": 32,
#             "accepted_answer_id": 72662159,
#             "answer_count": 1,
#             "score": 1,
#             "last_activity_date": 1655482469,
#             "creation_date": 1655008823,
#             "question_id": 72589514,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/72589514/does-perl-pdl-have-a-way-to-clamp-a-vector-by-min-max-values-given-in-another-ve",
#             "title": "Does Perl PDL have a way to clamp a vector by min/max values given in another vector without iterating?"
#         },
#         {
#             "tags": [
#                 "regex",
#                 "perl",
#                 "unicode"
#             ],
#             "owner": {
#                 "reputation": 18198,
#                 "user_id": 36498,
#                 "user_type": "registered",
#                 "accept_rate": 86,
#                 "profile_image": "https://www.gravatar.com/avatar/040b73282faf88b2eea3dc64507339c0?s=256&d=identicon&r=PG",
#                 "display_name": "alamar",
#                 "link": "https://stackoverflow.com/users/36498/alamar"
#             },
#             "is_answered": true,
#             "view_count": 69,
#             "accepted_answer_id": 72644809,
#             "answer_count": 2,
#             "score": -1,
#             "last_activity_date": 1655478501,
#             "creation_date": 1655377082,
#             "question_id": 72644739,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/72644739/perl-regex-how-to-get-multi-byte-optional-char-matching",
#             "title": "Perl regex: how to get multi-byte optional char (?) matching"
#         },
#         {
#             "tags": [
#                 "regex",
#                 "perl"
#             ],
#             "owner": {
#                 "reputation": 103,
#                 "user_id": 4253396,
#                 "user_type": "registered",
#                 "accept_rate": 25,
#                 "profile_image": "https://www.gravatar.com/avatar/9d208cf805bbea9d65d4d4a32e8d06d0?s=256&d=identicon&r=PG&f=1",
#                 "display_name": "sda",
#                 "link": "https://stackoverflow.com/users/4253396/sda"
#             },
#             "is_answered": true,
#             "view_count": 41,
#             "accepted_answer_id": 72658592,
#             "answer_count": 2,
#             "score": 1,
#             "last_activity_date": 1655464666,
#             "creation_date": 1655462402,
#             "question_id": 72658069,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/72658069/perl-regex-discriminate-mandatory-and-optional-characters",
#             "title": "Perl regex: discriminate mandatory and optional characters"
#         },
#         {
#             "tags": [
#                 "perl",
#                 "closures"
#             ],
#             "owner": {
#                 "reputation": 1583,
#                 "user_id": 2492415,
#                 "user_type": "registered",
#                 "accept_rate": 79,
#                 "profile_image": "https://www.gravatar.com/avatar/c954b90331feeb2a7a85148644239025?s=256&d=identicon&r=PG",
#                 "display_name": "Belmark Caday",
#                 "link": "https://stackoverflow.com/users/2492415/belmark-caday"
#             },
#             "is_answered": true,
#             "view_count": 8398,
#             "accepted_answer_id": 17039700,
#             "answer_count": 3,
#             "score": 23,
#             "last_activity_date": 1655455199,
#             "creation_date": 1370938707,
#             "last_edit_date": 1655454612,
#             "question_id": 17039427,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/17039427/how-does-the-closure-mechanism-work-in-perl",
#             "title": "How does the closure mechanism work in Perl?"
#         }
#     ],
#     "has_more": true,
#     "quota_max": 300,
#     "quota_remaining": 267
# }

# %% [markdown]
# En términos Pythonicos, podemos ver que el JSON es un diccionario que tiene 4 elementos:
#
# 1. items
# 2. has_more
# 3. quota_max
# 4. quota_remaining

# %% [markdown]
# ## 2. Obtener el número de respuestas contestadas y no contestadas

# %% [markdown]
# Para poder resolver esta pregunta debemos observar el JSON y notaremos que existen 2 elementos que nos sirven:
# "is_answered" & "answer_count"

# %% [markdown]
# Cabe mencionar, que si uno analiza a detalle el JSON se encontrará que si bien algún elemento "is_answered" puede contener la llave "false", aun así puede contener un número de respuestas, por lo que se vuelve un poco inconsistente nuestro análisis, para simplicidad por este caso, supondremos que lo que se desea saber es cuántas veces aparece "answer_count": 0 en el JSON.

# %%
#Primero observamos que podamos ingresar al valor de "is_answered"
data = json.loads(j)
print(data['items'][0]['answer_count'])
# Out:
# 0

# %% [markdown]
# El cuál coincide con el primer elemento de ITEMS del JSON.

# %%
#Ahora contaremos la cantidad de preguntas que no tuvieron respuesta
contador_no_respuestas=0
for i in data['items']:
    if i['answer_count'] == 0:
        contador_no_respuestas += 1
print(contador_no_respuestas)
# Out:
# 7

# %% [markdown]
# Afortunadamente en este caso podemos corroborar si es correcto o no, con la Evidencia 1.png

# %% [markdown]
# Ahora contaremos la cantidad de respuestas que tuvieron cada pregunta.

# %%
contador=0
for i in data['items']:
    contador+=i['answer_count']
print("El total de respuestas es: " + str(contador))
# Out:
# El total de respuestas es: 58

# %% [markdown]
# Nuevamente, afortunadamente podemos corroborar que nuestra lógica de programación fue correcta, de diversas maneras, por ejemplo, imprimir los valores de "answer_count" y luego utilizar alguna herramienta como Excel para hacer la suma de forma sencilla. Evidencia 2.png

# %%
for i in data['items']:
    print(i['answer_count'])
# Out:
# 0
# 1
# 0
# 7
# 2
# 12
# 0
# 1
# 2
# 0
# 3
# 1
# 2
# 1
# 3
# 4
# 4
# 0
# 1
# 0
# 1
# 2
# 1
# 1
# 1
# 0
# 1
# 2
# 2
# 3

# %% [markdown]
# ## 3. Obtener la respuesta con menor número de vistas

# %% [markdown]
# Debido a que el JSON contiene información de PREGUNTAS y en los metadatos sólo contiene si tiene respuestas o no, creo que la pregunta 3 está mal formulada.
#
# Debería ser: Obtener la pregunta con menor número de visitas.

# %%
#Vamos a buscar cual es la pregunta que tiene el "view_count" menor
min_view_count=100000
for i in data['items']:
    if i['view_count'] < min_view_count:
        min_view_count = i['view_count']
        min_view_count_question = i['title']
print("El título de la pregunta con menor cantidad de visitas es: " + min_view_count_question + "con un total de " + str(min_view_count) + " visitas")
# Out:
# El título de la pregunta con menor cantidad de visitas es: Perl form submit data to reactjscon un total de 22 visitas

# %% [markdown]
# ## 4. Obtener la pregunta más vieja y más actual

# %% [markdown]
# Aquí podemos observar que el tipo de fecha está codificado de una forma extraña, que la verdad no sé cuál sea su codificación, al momento de cargar el JSON se debería revisar a detalle este tipo de dato que nos está causando conflicto para poder determinar de forma correcta cuál sería el tipo de dato de fecha que se está utilizando, de momento no logro saber cuál es, Evidencia 3.png. Por lo pronto, supondremos que las fechas están en enteros y mientras mayor sea el entero más reciente es la fecha.

# %%
#Vamos a obtener cuál es la pregunta con la fecha más reciente y más antigua
max_creation_date=0
for i in data['items']:
    if i['creation_date'] > max_creation_date:
        max_creation_date = i['creation_date']
        max_creation_date_question = i['title']
print("El título de la pregunta con la fecha más reciente es: " + max_creation_date_question + "con una fecha de creación de " + str(max_creation_date))

min_creation_date=165591130700
for i in data['items']:
    if i['creation_date'] < min_creation_date:
        min_creation_date = i['creation_date']
        min_creation_date_question = i['title']
print("El título de la pregunta con la fecha más antigua es: " + min_creation_date_question + "con una fecha de creación de " + str(min_creation_date))
# Out:
# El título de la pregunta con la fecha más reciente es: How to create HTML tables dynamically using Perl?con una fecha de creación de 1655925551
# El título de la pregunta con la fecha más antigua es: How can I guess the encoding of a string in Perl?con una fecha de creación de 1262022733

# %% [markdown]
# ## 5. Obtener la pregunta del owner que tenga una mayor reputación

# %%
#Vamos a buscar cuál es la respuesta del owner con mayor "reputation"
max_reputation=0
for i in data['items']:
    if i['owner']['reputation'] > max_reputation:
        max_reputation = i['owner']['reputation']
        max_reputation_owner = i['owner']['display_name']
print("El nombre del usuario con mayor reputación es: " + max_reputation_owner + "con un total de " + str(max_reputation) + " reputación")
# Out:
# El nombre del usuario con mayor reputación es: David Bcon un total de 28046 reputación

# %% [markdown]
# ## 6. Imprimir en consola del punto 2 al 5
#
# El cual claramente fue realizado
